# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.196.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Using cached httplib2-0.31.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\rengan\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\rengan\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.28.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\rengan\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rengan\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\rengan\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.3)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\rengan\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rengan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rengan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rengan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rengan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\rengan\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\rengan\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\rengan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Downloading google_api_python_client-2.196.0-py3-none-any.whl (15.2 MB)
#    ---------------------------------------- 0.0/15.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.2 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/15.2 MB 2.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/15.2 MB 2.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.1/15.2 MB 2.7 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/15.2 MB 2.9 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.2 MB 3.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.2/15.2 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 5.0/15.2 MB 3.1 MB/s eta 0:00:04
#    --------------- ------------------------ 5.8/15.2 MB 3.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.3/15.2 MB 3.1 MB/s eta 0:00:03
#    ------------------ --------------------- 7.1/15.2 MB 3.2 MB/s eta 0:00:03
#    ------------------- -------------------- 7.6/15.2 MB 3.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.4/15.2 MB 3.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.9/15.2 MB 3.2 MB/s eta 0:00:02
#    ------------------------- -------------- 9.7/15.2 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 10.2/15.2 MB 3.2 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.2 MB 3.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.7/15.2 MB 3.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.0/15.2 MB 2.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.0/15.2 MB 2.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.3/15.2 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.3/15.2 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/15.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/15.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 11.5/15.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 11.8/15.2 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 11.8/15.2 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 11.8/15.2 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.2 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 12.1/15.2 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.3/15.2 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.3/15.2 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.3/15.2 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 12.3/15.2 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 12.6/15.2 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 12.6/15.2 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 12.8/15.2 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 12.8/15.2 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.1/15.2 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.1/15.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/15.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.4/15.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.6/15.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.6/15.2 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.6/15.2 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------ --- 13.9/15.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.9/15.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.9/15.2 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.2 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.2 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.2 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.2/15.2 MB 1.2 MB/s  0:00:12
# Downloading google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Downloading google_auth-2.53.0-py3-none-any.whl (246 kB)
# Downloading google_auth_httplib2-0.4.0-py3-none-any.whl (9.5 kB)
# Using cached httplib2-0.31.2-py3-none-any.whl (91 kB)
# Downloading proto_plus-1.28.0-py3-none-any.whl (50 kB)
# Using cached uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Installing collected packages: uritemplate, proto-plus, httplib2, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
#
#    ----------------- ---------------------- 3/7 [google-auth]
#    ----------------- ---------------------- 3/7 [google-auth]
#    ---------------------------- ----------- 5/7 [google-api-core]
#    ---------------------------- ----------- 5/7 [google-api-core]
#    ---------------------------------- ----- 6/7 [google-api-python-client]
#    ---------------------------------- ----- 6/7 [google-api-python-client]
#    ---------------------------------- ----- 6/7 [google-api-python-client]
#    ---------------------------------- ----- 6/7 [google-api-python-client]
#    ---------------------------------- ----- 6/7 [google-api-python-client]
#    ---------------------------------------- 7/7 [google-api-python-client]
#
# Successfully installed google-api-core-2.30.3 google-api-python-client-2.196.0 google-auth-2.53.0 google-auth-httplib2-0.4.0 httplib2-0.31.2 proto-plus-1.28.0 uritemplate-4.2.0

# %%
# ============================================================
# CELL 1 — Imports & Setup
# ============================================================
import os
import sys
import time
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from dotenv import load_dotenv
from tqdm import tqdm
from datetime import datetime

sys.path.append(os.path.abspath('..'))

# Load API key from .env file (NEVER hardcode it)
load_dotenv()
API_KEY = os.getenv("YOUTUBE_API_KEY")

if not API_KEY:
    raise ValueError("YOUTUBE_API_KEY not found. Add it to your .env file.")

print("✅ API Key loaded successfully.")
print(f"Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 21
#      18 API_KEY = os.getenv("YOUTUBE_API_KEY")
#      20 if not API_KEY:
# ---> 21     raise ValueError("YOUTUBE_API_KEY not found. Add it to your .env file.")
#      23 print("✅ API Key loaded successfully.")
#      24 print(f"Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
#
# ValueError: YOUTUBE_API_KEY not found. Add it to your .env file.
